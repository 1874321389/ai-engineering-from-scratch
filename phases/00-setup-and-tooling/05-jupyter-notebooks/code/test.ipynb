# %%
import numpy as np
data = np.random.randn(1000)
data.mean(), data.std()
# Out:
# (np.float64(-0.0002685995675462478), np.float64(0.9723621906146945))

# %%
# %timeit np.random.randn(10000)
# Out:
# 109 μs ± 850 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
import numpy as np

# 方法1：Python 列表推导式
# %timeit [np.random.randn() for _ in range(100_000)]

# 方法2：NumPy 向量化
# %timeit np.random.randn(100_000)
# Out:
# 18.2 ms ± 102 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.07 ms ± 4.85 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# # 数据分析示例
#
# 加载数据、展示表格、绘制图表。

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 创建一个示例 DataFrame（如果你没有 CSV 文件）
df = pd.DataFrame({
    "month": ["Jan", "Feb", "Mar", "Apr", "May"],
    "sales": [120, 150, 180, 140, 200]
})
df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import pandas as pd
#       2 import matplotlib.pyplot as plt
#       3
#       4 # 创建一个示例 DataFrame（如果你没有 CSV 文件）
#
# ModuleNotFoundError: No module named 'pandas'
